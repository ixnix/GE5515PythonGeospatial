# %% [markdown]
# ### 1. Simplifying the Great Lakes watershed basins
#
# In this problem you will apply different tolerance levels to simplify the watershed boundaries of Great Lakes.
#
# #### (a)
# - Read in the file `greatlakes_subbasins.zip` as a geopandas GeoDataFrame `lakes`. Print it out.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (b)
# - Print out the crs attribute of `lakes`. You can see that `lakes` has a Geographic projection and the coordinates are represented in degrees.
# - You need to first convert the projection of `lakes` to epsg=3175, which is a projected coordinate system for Canada and United States (USA) - Great Lakes basin and St Lawrence Seaway. The coordinates are now represented in meters.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (c)
# - Make two copies of `lakes` using the `.copy()` method. Name them as `lakes_copy1` and `lakes_copy2`.
# - Simplify the geometries in `lakes_copy1` using a tolerance value of 10 km.
# - Simplify the geometries in `lakes_copy2` using a tolerance value of 50 km.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (d)
# - Create subplots with three panels (1 row, 3 columns) using `plt.subplots()`; Set figsize to (10,8). Check Module 6 lecture note for hint.
# - From left to right, plot the `lakes`, `lakes_copy1`, and `lakes_copy2` on each panel.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (e)
# - Calculate the changes (in percentage) in watershed areas after simplifying the geometries, as (simplified-original)/original*100
# - Round all numbers to 2 decimal places.
# - Print a message: The total watershed area of Great Lakes is x km2. where x is the total watershed area in the original `lakes` GeoDataFrame.
# - Print a message: The total watershed area is x% smaller after simplification using a tolerance of 10 km.
# - Print a message: The total watershed area is x% smaller after simplification using a tolerance of 50 km.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (f)
# - Repeat the above step, but for the total perimeter of the watersheds. Use a length unit of km.
# - You will notice that perimeter changes are much larger than changes in the area.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### 2. Reclassify and aggregate data
#
# In this problem you will apply reclassification and aggregation to the `uscounties` dataset using geopandas, and perform similar analysis and mapping as the [Lab 7 of GIS Fundamentals textbook](https://www.gisfundamentals.org/resources).
#
# #### (a)
# - Read in the file `USCounties.zip` as a geopandas GeoDataFrame `uscounty`. Print out the list of columns.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (b)
# - Create a new column `AgeIndex` as the ratio of people above 65 (`Age65plus`) to people 21 and under (`AgeUnder21`), then multiplied by 100.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (c)
# - Create a new column `OldCounty` by applying a custom classifier to identify the counties that meet two criteria: (1) `AgeIndex` above 85 and (2) total population (`POP2000`) above 150,000. Check the lecture note on how to apply a self-defined classifier.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (d)
# - Plot both `AgeIndex` and `OldCounty` on a map, similar to the map in [Page 11 of ArcGISPro Lab 7](https://www.dropbox.com/scl/fo/n6mfee06ik6cnzdkhoyx6/AIxY7olKPbN9eJcGqTuMiPs/ArcGISPro/LabDirectionsArcGIS?dl=0&preview=Lab07_Tables_ArcGIS.pdf&rlkey=68tznzb9wf9wiit9rdtwf8rp8&subfolder_nav_tracking=1).
# - import matplotlib.pyplot as plt
# - Use `ax1 = uscounty.plot()` to plot `AgeIndex` in a map. Use `quantiles` classification scheme, 9 classes, `Blues` colormap.
# - Add the old county polygons to the map (by applying a filter based on `OldCounty`). Set `ax = ax1` and color to `yellow`.
# - To turn off the axes, use `plt.axis('off')`.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (e)
# - Find out where Old Counties are located.
# - You need to first filter `uscounty` based on `OldCounty`, and then apply `.value_counts()` on the `STATE_NAME` column.
# - Your result should be a pandas Series, with `STATE_NAME` as the index.
# - Print a message: There are a total of x old counties: y in A, z in B, o in C ... (where x, y, z, o are numbers; A, B, C are state names.)

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (f)
# - Create a new column `CPSM` (cows per square miles) using the `Cows` and `CountyAcre` columns: CPSM=Cows/(CountyAcre / 640)
# - Plot `CPSM` on a map; Use quantiles classification scheme, 10 classes, `RdYlGn_r` cmap.
# - Verify your result with the map on [Page 16 of ARCGIS PRO Lab 7](https://www.dropbox.com/scl/fo/n6mfee06ik6cnzdkhoyx6/AIxY7olKPbN9eJcGqTuMiPs/ArcGISPro/LabDirectionsArcGIS?dl=0&preview=Lab07_Tables_ArcGIS.pdf&rlkey=68tznzb9wf9wiit9rdtwf8rp8&subfolder_nav_tracking=1).

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (g)
# - Filter `uscounty` to select the rows for Michigan only; Name the output `michigan`.
# - Create a new column `M2F_Ratio` in `michigan`, calculated as the ratio of `MALES` to `FEMALES`.
# - Add a new column `M2F_Flag` which takes a value of 1 if M2F_Ratio>1 else 0. Hint: apply a custom classifier to `M2F_Ratio`.
# - Use `.dissolve()` to aggregate `michigan` based on `M2F_Flag`; Apply sum statistics on `CropAcres` and `Cows`, and mean statistics on `FrmrAge`.
# - Print out your output, which should be a GeoDataFrame with only 2 rows and 4 columns.

# %%
# ADD YOUR OWN CODE HERE
