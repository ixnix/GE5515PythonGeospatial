# %% [markdown]
# ### 1. Create a polygon from a list of coordinates
#
# In this problem, your task is to create a polygon based on the provided coordinates and plot the polygon in a map. Two lists, `longitudes` and `latitudes`, contain the input coordinates for the polygon. You need to first ‘assemble’ the coordinates to individual tuples of one longitude and one latitude coordinate each.

# %%
# Longitudes in decimal degrees
longitudes = [29.99671173095703, 31.58196258544922, 27.738052368164062, 26.50013542175293, 26.652359008789062, 25.921663284301758, 22.90027618408203, 23.257217407226562,
           23.335693359375, 22.87444305419922, 23.08465003967285, 22.565473556518555, 21.452774047851562, 21.66388702392578, 21.065969467163086, 21.67659568786621,
           21.496871948242188, 22.339998245239258, 22.288192749023438, 24.539581298828125, 25.444232940673828, 25.303749084472656, 24.669166564941406, 24.689163208007812,
           24.174999237060547, 23.68471908569336, 24.000761032104492, 23.57332992553711, 23.76513671875, 23.430830001831055, 23.6597900390625, 20.580928802490234, 21.320831298828125,
           22.398330688476562, 23.97638702392578, 24.934917449951172, 25.7611083984375, 25.95930290222168, 26.476804733276367, 27.91069221496582, 29.1027774810791, 29.29846954345703,
           28.4355525970459, 28.817358016967773, 28.459857940673828, 30.028610229492188, 29.075136184692383, 30.13492774963379, 29.818885803222656, 29.640830993652344, 30.57735824584961,
           29.99671173095703]

# Latitudes in decimal degrees
latitudes = [63.748023986816406, 62.90789794921875, 60.511383056640625, 60.44499588012695, 60.646385192871094, 60.243743896484375, 59.806800842285156, 59.91944122314453,
           60.02395248413086, 60.14555358886719, 60.3452033996582, 60.211936950683594, 60.56249237060547, 61.54027557373047, 62.59798049926758, 63.02013397216797,
           63.20353698730469, 63.27652359008789, 63.525691986083984, 64.79915618896484, 64.9533920288086, 65.51513671875, 65.65470886230469, 65.89610290527344, 65.79151916503906,
           66.26332092285156, 66.80228424072266, 67.1570053100586, 67.4168701171875, 67.47978210449219, 67.94589233398438, 69.060302734375, 69.32611083984375, 68.71110534667969,
           68.83248901367188, 68.580810546875, 68.98916625976562, 69.68568420410156, 69.9363784790039, 70.08860778808594, 69.70597076416016, 69.48533630371094, 68.90263366699219,
           68.84700012207031, 68.53485107421875, 67.69471740722656, 66.90360260009766, 65.70887756347656, 65.6533203125, 64.92096710205078, 64.22373962402344, 63.748023986816406]

# %% [markdown]
# a) Create a shapely.geometry.Polygon geometry based on the coordinates
#
# - Create a list of coordinate pairs, `coordinate_pairs`, based on the longitudes and latitudes. A coordinate pair can be either a tuple or a list.
# - Create a shapely.geometry.Polygon using the `coordinate_pairs`. Store the polygon in a variable `polygon`.

# %%
# ADD YOUR OWN CODE HERE


# Check the first coordinate pair. 
# Output of the following code should be: (29.99671173095703, 63.748023986816406)
# print(coordinate_pairs[0])

# %% [markdown]
# b) Insert the polygon into a newly created geopandas.GeoDataFrame called `geo`. Be sure to define a coordinate reference system for the data (the coordinates are in WGS84 format).

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# c) Plot the data set.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# d) Save the GeoDataFrame to a file. Save the file in GeoPackage format to the `data` directory, and name it `assignment3_polygon.gpkg`.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# ### 2. Points to map
#
# In this task, we learn how to create geometries from a set of latitude and longitude coordinates that are stored in a csv file. The input data is stored in the CSV spreadsheet `social_media_posts.csv`. The coordinates are in WGS84 format (decimal degrees, EPSG:4326), and the first few rows look like this:
#
# ```
# lat,lon,timestamp,userid
# -24.980792492,31.484633302,2015-07-07 03:02,66487960
# -25.499224667,31.508905612,2015-07-07 03:18,65281761
# -24.342578456,30.930866066,2015-03-07 03:38,90916112
# -24.85461393,31.519718439,2015-10-07 05:04,37959089
# ```
#
# The data consist of locations and times of social media posts inside Kruger national park in South Africa:
#
# | Column | Description |
# |--------|-------------|
# | lat | y-coordinate of the post |
# | lon | x-coordinate of the post |
# | timestamp | Time when the post was uploaded |
# | userid | unique id for each user|

# %% [markdown]
# a) Read the CSV file
#
# - Read the data into a Pandas dataframe called `data`

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# b) Add a geometry column and fill it with geometries
#
# - Create a column called `geometry` in `data` where you will store shapely Point objects based on the coordinate columns `lat` and `lon`.
# - You need to create a shapely.geometry.Point *for each row*, based on the lon and lat columns.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# c) Convert the pandas.DataFrame into a geopandas.GeoDataFrame
#
# - Convert `data` into a geopandas.GeoDataFrame.
# - Make sure that the resulting GeoDataFrame has a coordinate reference system defined.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# d) Save the data in Shapefile format as `social_media_posts.shp` inside the `data` directory

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# e) Create a simple map of the points

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# ### 3. How far did people travel?
#
# In this task, you will calculate the distance (in meters) that each social media user has travelled in-between the posts. We’re interested in the Euclidean distance between subsequent points generated by the same user.
#
# For this, we will need to use the `userid` column of the data.

# %% [markdown]
# a) Read the input file and re-project it
#
# - Read the input shapefile into a GeoDataFrame `gdf`.
# - Transform `gdf` from WGS84 to an `EPSG:32735` projection (UTM Zone 35S, suitable for South Africa). This CRS has *metres* as units.

# %%
# ADD YOUR CODE HERE



# Check that the crs is correct after re-projecting (should be epsg:32735)
#import pyproj
#kruger_points.crs == pyproj.CRS("EPSG:32735")

# %% [markdown]
# b) Group the data by user id
#
# Group the data by `userid` and store the grouped data in a variable `grouped_by_users`

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# c) Create shapely.geometry.LineString objects for each user connecting the points from the oldest to the most recent.
# - Create an empty list, `movement_data`.
# - Use a for-loop to iterate over the grouped object. For each userid’s data:
#     - [sort](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html) the rows by timestamp
#     - create a shapely.geometry.LineString based on the user’s points
#     - **CAREFUL**: Remember that every LineString needs at least two points. Skip users who have fewer than two posts.
#     - construct a dictionary {'userid': _userid_, 'geometry': _linestring_}, and append the dictionary into `movement_data`.
#
# - Convert `movement_data` into a geopandas.GeoDataFrame `movement`, and remember to assign a CRS.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# d) Calculate the distance between all posts of a user
#
# - Check that the CRS of the data frame is correct
# - Compute the lengths of the lines, and store the result in a new column called `distance`

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# e) Answer the following questions
# - What was the mean distance travelled per user (in meters)?
# - What was the maximum distance a user travelled (in meters)?

# %%
# ADD YOUR CODE HERE
