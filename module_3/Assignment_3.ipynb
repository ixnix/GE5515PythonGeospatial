# %% [markdown]
# # Assignment 3: Working with GeoDataFrames
#
# In this assignment, you will create geometries from coordinates, build GeoDataFrames, save geospatial files, and calculate distances.
#
# **Data files:** `social_media_posts.csv` (in your `data/` folder)
#
# **Submission:** Submit your completed `.ipynb` notebook file with all code cells executed and outputs visible.

# %% [markdown]
# ### 1. Create a polygon from a list of coordinates
#
# Your task is to create a polygon based on the provided coordinates and plot it on a map. Two lists, `longitudes` and `latitudes`, contain the input coordinates for the polygon.

# %%
# Longitudes in decimal degrees
longitudes = [29.99671173095703, 31.58196258544922, 27.738052368164062, 26.50013542175293, 26.652359008789062, 25.921663284301758, 22.90027618408203, 23.257217407226562,
           23.335693359375, 22.87444305419922, 23.08465003967285, 22.565473556518555, 21.452774047851562, 21.66388702392578, 21.065969467163086, 21.67659568786621,
           21.496871948242188, 22.339998245239258, 22.288192749023438, 24.539581298828125, 25.444232940673828, 25.303749084472656, 24.669166564941406, 24.689163208007812,
           24.174999237060547, 23.68471908569336, 24.000761032104492, 23.57332992553711, 23.76513671875, 23.430830001831055, 23.6597900390625, 20.580928802490234, 21.320831298828125,
           22.398330688476562, 23.97638702392578, 24.934917449951172, 25.7611083984375, 25.95930290222168, 26.476804733276367, 27.91069221496582, 29.1027774810791, 29.29846954345703,
           28.4355525970459, 28.817358016967773, 28.459857940673828, 30.028610229492188, 29.075136184692383, 30.13492774963379, 29.818885803222656, 29.640830993652344, 30.57735824584961,
           29.99671173095703]

# Latitudes in decimal degrees
latitudes = [63.748023986816406, 62.90789794921875, 60.511383056640625, 60.44499588012695, 60.646385192871094, 60.243743896484375, 59.806800842285156, 59.91944122314453,
           60.02395248413086, 60.14555358886719, 60.3452033996582, 60.211936950683594, 60.56249237060547, 61.54027557373047, 62.59798049926758, 63.02013397216797,
           63.20353698730469, 63.27652359008789, 63.525691986083984, 64.79915618896484, 64.9533920288086, 65.51513671875, 65.65470886230469, 65.89610290527344, 65.79151916503906,
           66.26332092285156, 66.80228424072266, 67.1570053100586, 67.4168701171875, 67.47978210449219, 67.94589233398438, 69.060302734375, 69.32611083984375, 68.71110534667969,
           68.83248901367188, 68.580810546875, 68.98916625976562, 69.68568420410156, 69.9363784790039, 70.08860778808594, 69.70597076416016, 69.48533630371094, 68.90263366699219,
           68.84700012207031, 68.53485107421875, 67.69471740722656, 66.90360260009766, 65.70887756347656, 65.6533203125, 64.92096710205078, 64.22373962402344, 63.748023986816406]

# %% [markdown]
# #### (a) Create the polygon
#
# - Create a list of coordinate pairs, `coordinate_pairs`, based on the longitudes and latitudes. A coordinate pair can be either a tuple or a list.
# - Create a `shapely.geometry.Polygon` using the `coordinate_pairs`. Store it in a variable `polygon`.
#
# **Hint:** Use `zip(longitudes, latitudes)` to pair up the coordinates.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (b) Create a GeoDataFrame
#
# Insert the polygon into a newly created `geopandas.GeoDataFrame` called `geo`. Be sure to define a coordinate reference system (the coordinates are in WGS84 / EPSG:4326).
#
# **Hint:** `gpd.GeoDataFrame(geometry=[polygon], crs='EPSG:4326')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Plot the data
#
# Plot the GeoDataFrame using `.plot()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (d) Save to file
#
# Save the GeoDataFrame in GeoPackage format to the `data` directory as `assignment3_polygon.gpkg`.
#
# **Hint:** Use `.to_file('data/assignment3_polygon.gpkg', driver='GPKG')`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 2. Points to map
#
# In this task, you will create geometries from latitude/longitude coordinates stored in a CSV file. The input data is in `data/social_media_posts.csv`. The coordinates are in WGS84 (EPSG:4326), and the first few rows look like this:
#
# ```
# lat,lon,timestamp,userid
# -24.980792492,31.484633302,2015-07-07 03:02,66487960
# -25.499224667,31.508905612,2015-07-07 03:18,65281761
# ```
#
# The data consist of social media post locations inside Kruger National Park, South Africa:
#
# | Column | Description |
# |--------|-------------|
# | lat | y-coordinate of the post |
# | lon | x-coordinate of the post |
# | timestamp | Time when the post was uploaded |
# | userid | Unique ID for each user |

# %% [markdown]
# #### (a) Read the CSV file
#
# Read the data into a pandas DataFrame called `data`.
#
# **Hint:** `pd.read_csv('data/social_media_posts.csv')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (b) Add a geometry column
#
# - Create a column called `geometry` in `data` with shapely `Point` objects based on the `lon` and `lat` columns.
# - **Important:** Point takes coordinates as `(longitude, latitude)`, i.e., `(x, y)` order.
#
# **Hint:** Use `gpd.points_from_xy(data.lon, data.lat)` or a list comprehension with `Point(lon, lat)`.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Convert to GeoDataFrame
#
# Convert `data` into a `geopandas.GeoDataFrame` and define the CRS as EPSG:4326.
#
# **Hint:** `gpd.GeoDataFrame(data, geometry='geometry', crs='EPSG:4326')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (d) Save as Shapefile
#
# Save the GeoDataFrame as `data/social_media_posts.shp`.
#
# **Hint:** Use `.to_file('data/social_media_posts.shp')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (e) Create a map
#
# Create a simple map of the points using `.plot()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 3. How far did people travel?
#
# In this task, you will calculate the distance (in meters) each user travelled between posts. We need the **Euclidean distance** between subsequent points by the same user.
#
# We will use the `userid` column to group the data.

# %% [markdown]
# #### (a) Read and reproject
#
# - Read the shapefile `data/social_media_posts.shp` into a GeoDataFrame `gdf`.
# - Reproject from WGS84 to `EPSG:32735` (UTM Zone 35S — suitable for South Africa). This CRS uses **metres** as units.
#
# **Hint:** `gdf = gdf.to_crs(epsg=32735)`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (b) Group by user
#
# Group the data by `userid` and store the result in `grouped_by_users`.
#
# **Hint:** `gdf.groupby('userid')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Create LineStrings for each user
#
# - Create an empty list `movement_data`.
# - Use a for loop to iterate over the grouped object. For each user:
#     - [Sort](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html) the rows by `timestamp`
#     - Create a `shapely.geometry.LineString` from the user's points
#     - **Important:** Skip users with fewer than 2 posts (a LineString needs at least 2 points)
#     - Append `{'userid': userid, 'geometry': linestring}` to `movement_data`
# - Convert `movement_data` to a `geopandas.GeoDataFrame` called `movement` with CRS EPSG:32735.
#
# **Hint:** Access the geometry coordinates with `.geometry.values` after sorting.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (d) Calculate distances
#
# - Verify the CRS is EPSG:32735.
# - Compute the length of each line and store in a new column `distance`.
#
# **Hint:** `movement['distance'] = movement.geometry.length`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (e) Answer questions
#
# - What was the **mean** distance travelled per user (in meters)?
# - What was the **maximum** distance a user travelled (in meters)?

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Summary
#
# In this assignment, you practiced:
# - Creating `Polygon` and `Point` geometries from coordinate lists
# - Building `GeoDataFrames` and setting CRS
# - Saving data in GeoPackage and Shapefile formats
# - Reprojecting data between coordinate reference systems
# - Using `groupby` to analyze movement patterns per user
#
# **Don't forget to save your notebook before submitting!**
