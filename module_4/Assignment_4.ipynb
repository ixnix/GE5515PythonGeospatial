# %% [markdown]
# ### 1. Explain the difference between a geographic CRS and a projected CRS. Provide one example of each.

# %% [markdown]
# Your answer:

# %% [markdown]
# ### 2. What are EPSG codes? Give the EPSG codes for WGS 84 (global lat/lon) and UTM zone 16N (covers part of Michigan).

# %% [markdown]
# Your answer:

# %% [markdown]
# ### 3. In the following questions, you will compare different CRS for the state of Minnesota.
# - Load the `Minnesota.shp.zip` file using geopandas into a GeoDataFrame `gdf`.
# - Print its CRS and describe whether it is geographic or projected.
# - What is the name of the projection?

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# - Transform the dataset into the following two projected CRS. Name the output `gdf_reproj1` and `gdf_reproj2`.
# - EPSG:32616 (UTM Zone 16N)
# - EPSG:3395 (Mercator)
# - What are the coordinates (centroid) of Ramsey County in the original CRS and the two transformed CRS?

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# - Plot the county boundaries of `gdf`, `gdf_reproj1`, and `gdf_reproj2` side by side in the same figure.
# - Add titles to show the CRS of each plot.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# - Add a column to the three GeoDataFrames that store the area of each county in square kilometers.
# - Print the total areas of all counties.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# - Create three choropleth maps side by side to show the county areas in square kilometers in `gdf`, `gdf_reproj1`, and `gdf_reproj2`.
# - Set vmin to 0 and vmax to 50,000. Use `turbo` cmap.

# %%
# ADD YOUR OWN CODE HERE
