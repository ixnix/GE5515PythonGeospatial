# %% [markdown]
# # Assignment 4: Coordinate Reference Systems
#
# In this assignment, you will explore how different coordinate reference systems affect area calculations and map visualizations.
#
# **Data file:** `Minnesota.shp.zip` (in your `data/` folder)
#
# **Submission:** Submit your completed `.ipynb` notebook file with all code cells executed and outputs visible.

# %% [markdown]
# ### 1. Geographic vs. Projected CRS
#
# Explain the difference between a geographic CRS and a projected CRS. Provide one example of each.
#
# **Hint:** Think about what units each system uses and how the Earth's surface is represented.

# %% [markdown]
# Your answer:

# %% [markdown]
# ### 2. EPSG codes
#
# What are EPSG codes? Give the EPSG codes for:
# - WGS 84 (global lat/lon)
# - UTM Zone 16N (covers part of Michigan)

# %% [markdown]
# Your answer:

# %% [markdown]
# ### 3. Comparing CRS for Minnesota
#
# In the following questions, you will compare different CRS for the state of Minnesota.
#
# #### (a) Load and inspect
# - Load `data/Minnesota.shp.zip` using geopandas into a GeoDataFrame `gdf`.
# - Print its CRS and describe whether it is geographic or projected.
# - What is the name of the projection?

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (b) Reproject
#
# Transform the dataset into two projected CRS. Name the outputs `gdf_reproj1` and `gdf_reproj2`:
# - EPSG:32616 (UTM Zone 16N)
# - EPSG:3395 (Mercator)
#
# What are the coordinates (centroid) of Ramsey County in the original CRS and the two reprojected CRS?
#
# **Hint:** Use `.to_crs(epsg=...)` to reproject, and filter by county name to find Ramsey County.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Plot boundaries
#
# Plot the county boundaries of `gdf`, `gdf_reproj1`, and `gdf_reproj2` side by side using `plt.subplots(1, 3)`.
# Add titles to show the CRS of each plot.
#
# **Hint:** `fig, axes = plt.subplots(1, 3, figsize=(15, 5))`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (d) Calculate areas
#
# - Add a column to each of the three GeoDataFrames that stores the area in **square kilometers** (divide by 1e6 if units are m²).
# - Print the total area of all counties for each CRS.
#
# **Note:** Areas calculated in geographic CRS (degrees²) are not meaningful — you should observe this in your results.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (e) Choropleth maps
#
# Create three choropleth maps side by side showing county areas in km² for `gdf`, `gdf_reproj1`, and `gdf_reproj2`.
# - Set `vmin=0` and `vmax=50000`
# - Use the `turbo` colormap
#
# **Hint:** `.plot(column='area_km2', vmin=0, vmax=50000, cmap='turbo', ax=ax)`

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Summary
#
# In this assignment, you practiced:
# - Distinguishing geographic and projected coordinate reference systems
# - Reprojecting GeoDataFrames between CRS using `.to_crs()`
# - Comparing how CRS choice affects area calculations
# - Creating side-by-side choropleth maps for visual comparison
#
# **Don't forget to save your notebook before submitting!**
