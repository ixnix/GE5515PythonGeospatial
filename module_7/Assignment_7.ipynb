# %% [markdown]
# # Assignment 7: Proximity Analysis
#
# In this assignment, you will use proximity analysis techniques to study the spatial relationship between metro stations and grocery stores in Washington DC.
#
# **Data files:**
# - `data/Metro_Stations_Regional.zip`
# - `data/Grocery_Store_Locations.zip`
#
# **Note:** GeoPandas can read `.zip` files directly — no need to unzip them first.
#
# **Submission:** Submit your completed `.ipynb` notebook file with all code cells executed and outputs visible.

# %% [markdown]
# ### 1. Proximity Analysis
#
# #### (a) Read data into GeoDataFrame
#
# - Read `data/Metro_Stations_Regional.zip` as a GeoDataFrame `stations`. Extract columns: `'NAME', 'ADDRESS', 'LINE', 'geometry'`.
# - Read `data/Grocery_Store_Locations.zip` as a GeoDataFrame `grocery`. Extract columns: `'STORENAME', 'ADDRESS', 'PHONE', 'geometry'`.
# - Print: "There are x metro stations and y grocery stores in Washington DC."
#
# **Hint:** `gpd.read_file('data/Metro_Stations_Regional.zip')[['NAME','ADDRESS','LINE','geometry']]`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (b) Match CRS
#
# - Check if `stations` and `grocery` have the same CRS.
# - If not, reproject `grocery` to match `stations`.
#
# **Hint:** `grocery = grocery.to_crs(stations.crs)`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Create buffers
#
# - Create a **3 km buffer** around the `Metro Center` station using boolean indexing on the `NAME` column.
# - Name your output `buffer` — it should be a `GeoSeries`. Use `type()` to verify.
#
# **Hint:** `buffer = stations[stations['NAME'] == 'Metro Center'].geometry.buffer(3000)`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (d) Visualize and explore
#
# - Plot `stations`, `grocery`, and `buffer` on an interactive map using `.explore()`.
# - Use **red** for stations, **blue** for grocery stores, and **yellow** for the buffer.
#
# **Hint:** Chain `.explore()` calls: `m = buffer.explore(color='yellow'); stations.explore(m=m, color='red'); grocery.explore(m=m, color='blue')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (e) Find stations within buffer
#
# - Use the buffer to select metro stations **within** the buffer area.
# - Construct a boolean mask using the `within` spatial predicate.
# - **Important:** Spatial predicates require a `shapely.geometry.Polygon`, not a GeoSeries. Use `.iloc[0]` to extract the polygon.
# - Name the output `stations_buffer` (a filtered subset of `stations`).
# - Print: "x out of y stations are located within the buffer area."
#
# **Hint:** `mask = stations.within(buffer.iloc[0]); stations_buffer = stations[mask]`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (f) Find nearest grocery stores
#
# - Use nearest neighbor analysis to find the closest grocery store to each station in `stations_buffer`.
# - Name the output `closest_grocery`.
# - Print: "The shortest distance is x meters, and longest distance is y meters." (round to 2 decimals)
#
# **Hint:** Use `gpd.sjoin_nearest(stations_buffer, grocery, distance_col='distance')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (g) Nearest grocery within 1000 m search radius
#
# - Repeat the previous step with a **1000 m search radius** (`max_distance=1000`).
# - Name the output `closest_grocery_limit`.
# - Print: "The nearest grocery store from Dupont Circle station is X located at Y."
# - Use Python code to look up the answer — no credit for hard-coded values.
#
# **Hint:** `gpd.sjoin_nearest(stations_buffer, grocery, max_distance=1000, distance_col='distance')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (h) Visualize connecting lines
#
# In this step, you will draw straight lines connecting each metro station and its nearest grocery store.
#
# **Step 1 (h1):** Merge `closest_grocery_limit` with `grocery` to add grocery store coordinates. The merge will produce two geometry columns (`geometry_x` for stations, `geometry_y` for grocery stores).
#
# **Step 2 (h2):** Using `geometry_x` and `geometry_y`, create a new geometry column of `LineString` objects connecting each station to its nearest grocery store.
#
# **Step 3 (h3):** Visualize the results:
# - Black dots for grocery stores
# - Red squares for metro stations (from `stations_buffer`)
# - Blue solid lines for connecting lines
# - Figure size: 5×5
#
# **Hint for h2:** `from shapely.geometry import LineString; LineString([point1, point2])`

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Summary
#
# In this assignment, you practiced:
# - Creating buffer zones and filtering features spatially
# - Interactive map visualization with `.explore()`
# - Nearest neighbor analysis with `gpd.sjoin_nearest()`
# - Creating LineString geometries to visualize spatial relationships
#
# **Don't forget to save your notebook before submitting!**
