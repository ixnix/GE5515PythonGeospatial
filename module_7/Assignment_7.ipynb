# %% [markdown]
# ### 1. Proximity Analysis
#
# Use two geospatial datasets (metro stations and grocery stores in Washington DC) to perform proximity analysis and answer the following questions.
#
# #### (a) Read data into GeoDataFrame
# - Read in the file `Metro_Stations_Regional.zip` as a geopandas GeoDataFrame `stations`. Extract these columns only: 'NAME','ADDRESS','LINE','geometry'.
# - Read in the file `Grocery_Store_Locations.zip` as a geopandas GeoDataFrame `grocery`. Extract these columns only: 'STORENAME','ADDRESS','PHONE','geometry'.
# - Print a message: There are x metro stations and y grocery stores in Washington DC. (where x=length of `stations`; y=length of `grocery`).

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# #### (b) Match CRS
# - Check if `stations` and `grocery` have the same CRS.
# - If yes, do nothing.
# - If no, reproject `grocery` onto `stations`

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# #### (c) Create buffers
# - Create a 3 km buffer around the coordinates of the `Metro Center` station, using boolean indexing of the `NAME` column of `stations`.
# - Name your output `buffer`, which should be a geopandas GeoSeries. Use `type()` to verify your result.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# #### (d) Visualize and explore
# - Plot `stations`, `grocery`, and `buffer` on an interactive map. Check the lecture note for examples on `.explore()`.
# - Use the interactive map to get a first impression of which stations are located within the buffer.
# - Use red color for stations; blue for grocery stores; and yellow for buffer.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# #### (e) Find stations within buffer
# - In this step, you will use `buffer` to select the metro stations located within the buffer area. Review the previous lecture (Geocoding and Spatial Join), if needed.
# - You will construct a mask array based on the **within** spatial predicate to filter `stations`.
# - Note that the spatial predicates require a shapely.geometry.Polygon as input, NOT a GeoSeries. You can use .iloc[0] to extract the polygon geometry in `buffer`.
# - Name your output `stations_buffer`, which is a subset or slice of `stations` located within the buffer.
# - Print a message: x out of y stations are located within the buffer area. (where x=length of `stations_buffer`; y=length of `stations`).

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# #### (f) Find nearest grocery stores to metro stations
# - In this step, you will use nearest neighbor analysis to find the closest grocery store to each metro station in `stations_buffer`.
# - Name your output `closest_grocery`.
# - Print a message: The shortest distance is x meters, and longest distance is y meters. (x and y are the minimum and maximum of `distance` column. Round to 2 decimals).

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# #### (g) Find nearest grocery stores to metro stations within 1000 m search radius
# - Repeat the previous step, but limit the search radius to 1000 m. In other words, search for the grocery store within 1000 m distance for each station, if available.
# - Name your output `closest_grocery_limit`.
# - Print a message: The nearest grocery store from Dupont Circle station is x located at y. (where x is the store name; y is the address; Use python code to answer this question. No credit for hard-wired answers).

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# #### (h) Visualize the connecting lines between grocery stores and metro station
# - In this step, you will draw straight lines connecting each metro station and its nearest grocery store.
# - First, you will merge `closest_grocery_limit` with `grocery`, so that the coordinates of grocery stores can be added into `closest_grocery_limit`.
# - Then, using the geometry columns (`geometry_x` and `geometry_y`) of grocery stores and stations, you will create a new geometry column of LineString objects.
# - Visualize the stations (from `stations_buffer`) and grocery stores (from `grocery`), and the connecting lines (from `closest_grocery_limit`) in the same plot.
# - Set figure size to 5 by 5.
# - Use black dots for grocery stores; red square symbols for metro stations; blue solid lines for connecting lines.

# %%
# ADD YOUR CODE HERE
