# %% [markdown]
# # Assignment 14: Watershed Delineation and Analysis
#
# **Submission:** Submit your completed `.ipynb` notebook file with all code cells executed and outputs visible.
#
# ---

# %% [markdown]
# In this assignment you will practice the watershed delineation and analysis workflow covered in the lecture. You will use the **same DEM tile** (`n30_w100_1arc_v3.tif`) but delineate a **different watershed** by choosing a new pour point: the confluence of the North and South Llano Rivers near **Junction, TX** (30.489°N, 99.772°W). This location lies upstream of the Kerrville Lake Dam used in the lecture and drains a distinct portion of the Texas Hill Country.
#
# You may reuse and adapt code from the lecture notebook. The `basin_functions.py` helper module is available for import.

# %% [markdown]
# ### Problem 1. Load and condition the DEM

# %% [markdown]
# #### (a) Import libraries and load the DEM
#
# Import the necessary libraries (same as the lecture). Then read `data/n30_w100_1arc_v3.tif` using `rioxarray` and print the resulting `DataArray`.
#
# **Hint:** `import rioxarray; dem = rioxarray.open_rasterio('data/n30_w100_1arc_v3.tif')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (b) Create a pysheds Grid
#
# Extract the elevation data, affine transform, CRS, and nodata value from the `DataArray`. Use them to create pysheds `ViewFinder`, `Raster`, and `Grid` objects.
#
# **Hint:** Refer to the lecture notebook for the exact sequence of pysheds object creation.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Condition the DEM
#
# Perform the three hydrological conditioning steps in order:
# 1. Fill pits → verify with `assert`
# 2. Fill depressions → verify with `assert`
# 3. Resolve flats → print the number of flats detected before resolving
#
# Use `grid.detect_flats()` and `np.count_nonzero()` as shown in the lecture.
#
# **Hint:** `pit_filled = grid.fill_pits(dem_data); assert not grid.detect_pits(pit_filled).any()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Problem 2. Flow direction, accumulation, and watershed delineation

# %% [markdown]
# #### (a) Compute flow direction and accumulation
#
# Using the conditioned (inflated) DEM, compute the D8 flow direction grid and the flow accumulation grid. Print the maximum flow accumulation value.
#
# **Hint:** `fdir = grid.flowdir(inflated_dem); acc = grid.accumulation(fdir)`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (b) Define pour point and delineate watershed
#
# Set the pour point to the Llano River confluence near Junction, TX:
# - Longitude: **-99.772**
# - Latitude: **30.489**
#
# Snap the pour point to the nearest high-accumulation cell (accumulation > 1000) using `grid.snap_to_mask()`, then delineate the watershed using `grid.catchment()`.
#
# **Hint:**
# ```python
# x, y = -99.772, 30.489
# snap = grid.snap_to_mask(acc > 1000, (x, y))
# catch = grid.catchment(x=snap[0], y=snap[1], fdir=fdir)
# ```

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Visualize the watershed
#
# Clip the grid to the delineated watershed. Create a **2×2 subplot** showing:
# 1. Watershed extent
# 2. Watershed elevation
# 3. Flow direction
# 4. Flow accumulation (use `LogNorm` color scale)
#
# Add axis labels and a descriptive title (e.g., "Llano River watershed").
#
# **Hint:** `from matplotlib.colors import LogNorm; ax.imshow(acc_clipped, norm=LogNorm())`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Problem 3. Watershed analysis

# %% [markdown]
# #### (a) Distance to outlet
#
# Calculate the distance (in cells) from every cell in the watershed to the pour point using `grid.distance_to_outlet()`. Create a map with a colorbar.
#
# **Hint:** `dist = grid.distance_to_outlet(x=snap[0], y=snap[1], fdir=fdir)`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (b) Extract the river network
#
# Extract the river network for cells with flow accumulation > 200. Plot the channel segments with axis labels and a title.
#
# **Hint:** `branches = grid.extract_river_network(fdir, acc > 200)`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Hypsometric analysis
#
# Export the watershed elevations to an `xarray.DataArray` (refer to the lecture). Then:
# 1. Calculate the elevation histogram using 50 bins
# 2. Compute the normalized hypsometric curve
# 3. Calculate the hypsometric integral
# 4. Print the hypsometric integral value
#
# **Hint:** Use the `calculate_hypsometry()` and `calculate_hypsometric_integral()` functions from `basin_functions.py`.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (d) Plot the hypsometric curve
#
# Create a plot including:
# - Basin hypsometric curve (red line)
# - Dashed gray linear reference line (HI = 0.5)
# - Text annotation with the computed HI value
# - Axis labels: "Area fraction above elevation" (x) and "Elevation (m)" (y)

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Problem 4. Interpretation

# %% [markdown]
# #### (a) Classify the watershed
#
# Based on your hypsometric integral value, classify the Llano River watershed as:
# - **Youthful** (HI > 0.6) — little erosion
# - **Mature** (0.35–0.6) — moderate erosion
# - **Old** (HI < 0.35) — heavily eroded
#
# Explain what this tells you about the erosional state of the watershed in 2–3 sentences.

# %% [markdown]
# *Your answer here.*

# %% [markdown]
# #### (b) Compare watersheds
#
# Compare the hypsometric integral of your Llano River watershed to the Kerrville Lake Dam watershed from the lecture (HI ≈ 0.559). Which has experienced more erosion? Briefly explain why the two values might differ, considering drainage area, terrain, and geology.

# %% [markdown]
# *Your answer here.*

# %% [markdown]
# #### (c) Drainage pattern analysis
#
# Look at your river network plot from Problem 3(b). Describe the drainage pattern (e.g., dendritic, trellis, radial). In 2–3 sentences, explain how the underlying geology or topography of the Texas Hill Country might produce this pattern.

# %% [markdown]
# *Your answer here.*

# %% [markdown]
# ---
# ## Summary
#
# In this assignment, you practiced:
# - Loading and conditioning DEM data for hydrological analysis
# - Computing flow direction and accumulation grids
# - Delineating a watershed from a pour point
# - Extracting river networks and computing distance to outlet
# - Performing hypsometric analysis and interpreting erosional state
#
# **Don't forget to save your notebook before submitting!**
