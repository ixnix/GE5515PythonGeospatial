# %% [markdown]
# # Assignment 8: Vector Overlay Analysis
#
# In this assignment, you will use overlay analysis (intersection) to determine what percentage of each park's area falls within a buffer zone around a metro station.
#
# **Data files:**
# - `data/National_Parks.zip`
# - `data/metro_center.gpkg`
#
# **Submission:** Submit your completed `.ipynb` notebook file with all code cells executed and outputs visible.

# %% [markdown]
# ### 1. Vector Overlay Analysis
#
# #### (a) Read data
#
# - Read `data/National_Parks.zip` as a GeoDataFrame `parks`. Extract columns: `'NAME', 'ADDRESS', 'PARK_CODE', 'geometry'`.
# - Read `data/metro_center.gpkg` as a GeoDataFrame `metro_center`.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (b) Create buffer
#
# - Create a **3 km buffer** around `metro_center`.
# - Name the output `station_buffer`. It should be a **GeoDataFrame** (not just a GeoSeries), as this is needed for the overlay step.
#
# **Hint:** `station_buffer = metro_center.copy(); station_buffer['geometry'] = metro_center.geometry.buffer(3000)`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Visualize and explore
#
# - Visualize `parks` and `station_buffer` on the same interactive map using `.explore()`.
# - Plot `station_buffer` **first**, then `parks` on top, so the park polygons are visible.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (d) Perform overlay analysis
#
# - Perform an **intersection** overlay between `parks` and `station_buffer`.
# - Name the output `intersection`.
# - Print: "There are x park areas in Washington DC, and y park areas after the overlay analysis."
#
# **Hint:** `gpd.overlay(parks, station_buffer, how='intersection')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (e) Calculate park areas
#
# - Add a column `AREA` based on the `.area` attribute of the geometry.
# - Use `.groupby('NAME')` to sum the `AREA` column (some parks have multiple polygon features).
# - Name the output `park_area` — a pandas Series with `NAME` as the index.
#
# **Hint:** `park_area = parks.groupby('NAME')['AREA'].sum()`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (f) Calculate intersection areas
#
# - Repeat the previous step using `intersection` instead of `parks`.
# - Name the output `park_area_intersection`.
#
# This gives you the area of each park that falls *within* the buffer zone.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (g) Calculate percentage of park area in intersection
#
# - Create an empty pandas Series `percent` with the same index as `park_area_intersection`.
# - Use a **for loop** to calculate the percentage of each park's area that is in the intersection: `(intersection_area / total_area) * 100`
# - Round to 2 decimal places. Percentages should not exceed 100%.
# - Print: "x percent of the total area of East Potomac Park is included in the intersection."
#
# **Hint:** `percent = pd.Series(index=park_area_intersection.index, dtype=float)`
# Then loop: `for name in park_area_intersection.index: percent[name] = ...`

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Summary
#
# In this assignment, you practiced:
# - Creating buffer zones around features
# - Performing vector overlay analysis (intersection)
# - Calculating and comparing polygon areas
# - Using `groupby` for spatial aggregation
# - Computing area percentages with for loops
#
# **Don't forget to save your notebook before submitting!**
