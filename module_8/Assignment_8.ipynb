# %% [markdown]
# ### 1. Vector Overlay Analysis
#
# Use the National Parks and Metro Center station in Washington DC to perform overlay analysis and answer the following questions.
#
# #### (a) Read data
# - Read in `National_Parks.zip` as a geopandas GeoDataFrame `parks`. Extract these columns only: 'NAME','ADDRESS','PARK_CODE','geometry'.
# - Read in `metro_center.gpkg` as a geopandas GeoDataFrame `metro_center`.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# #### (b) Create buffer
# - Create a 3 km buffer around `metro_center`.
# - Name your output `station_buffer`.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# #### (c) Visualize and explore
# - Visualize `parks` and `station_buffer` on the same interactive map using `.explore()`.
# - Unlike in the lecture note, you need to plot `station_buffer` first, and `parks` afterwards, so that the `parks` layer sits on top of `station_buffer`.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# #### (d) Perform overlay analysis
# - Perform overlay analysis using intersection operation between `parks` and `station_buffer`.
# - Name your output `intersection`.
# - Print a message: There are x park areas in Washington DC, and y park areas after the overlay analysis. (where x=length of `parks`; y=length of `intersection`)

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# #### (e) Calculate the areas of parks
# - In this step, you will calculate the areas of each park in `parks`.
# - First, add a new column `AREA` based on the area attribute of the geometry column.
# - Then, perform groupby() operation on the `NAME` column by adding up the `AREA` column. The reason is that there may be multiple rows or polygon features for the same park name.
# - Name your output `park_area`, which is a pandas Series with NAME as index.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# #### (f) Calculate the areas of parks within the intersection
# - As you have learned in the lecture, intersection operation only keeps the features from `parks` within the buffer, and may also create new polygon features by splitting some polygons.
# - Repeat the above step, but based on `intersection`. In other words, calculate the area of each park included in `intersection`.
# - Name your output, `park_area_intersection`.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# #### (g) Calculate percentage of park area in the intersection
# - In this step, you will calculate the percentage of area for each park in `intersection` out of the total park area in `parks`.
# - First, create an empty pandas Series `percent` to store your output; set the index to the same as `park_area_intersection`. Hint: use `pd.Series()`.
# - Then, create a **for loop** on `park_area_intersection`, to calculate the percentage of each park area to the area of the same park in `parks`. Round to 2 decimal places.
# - The percentage should not exceed 100%.
# - From your result, print a message: x percent of the total area of East Potomac Park is included in the intersection overlay analysis. (where x is the percentage value for `East Potomac Park`)

# %%
# ADD YOUR CODE HERE
