# %% [markdown]
# ### 1. Point geometry
# - Create a shapely point object _point1_ with coordinates (0, 1)
# - Print the following attributes of _point1_:
#     - wkt
#     - geom_type
#     - coords (convert to list)
#     - x
#     - y
# - Create another point _point2_ with coordinates (0, 5)
# - Calculate the distance between _point1_ and _point2_
# - Create a circle, _cir1_, with a radius of 2 and center at _point1_ using the [.buffer() method of Point object](https://shapely.readthedocs.io/en/2.0.6/reference/shapely.Point.html).
# - Print the wkt attribute of _cir1_

# %%
# Add your code here

# %% [markdown]
# ### 2. LineString geometry
# - Create a shapely linestring object, _line1_, using _point1_ and _point2_ defined in Q1
# - Print the following attributes of _line1_:
#     - wkt
#     - geom_type
#     - coords (convert to list)
#     - xy
#     - length
#     - centroid

# %%
# Add your code here

# %% [markdown]
# ### 3. Polygon geometry
# - Create a pentagon, _poly1_, using coordinates `(30, 2.01), (31.91, 0.62), (31.18, -1.63), (28.82, -1.63), (28.09, 0.62)`
# - Print the following attributes:
#     - wkt
#     - geom_type
#     - area
#     - bounds
#     - centroid
#     - exterior
#     - exterior length

# %%
# Create and display the polygon here

# %%
# print attributes here

# %% [markdown]
# ### 4. Polygon with holes
# - The bounds attribute of polygons returns a tuple of minx, miny, maxx, maxy values.
# - Create a polygon, _poly2_, using the bounds of _poly1_ as the exterior ring, and _poly1_ itself as the interior ring.
# - Print the following attributes:
#     - wkt
#     - geom_type
#     - coords
#     - area
#     - bounds
#     - centroid
#     - exterior
#     - exterior length
#     - interiors (name the output _holes_)
# - Compare the area, bounds, and centroid attributes with those of _poly1_, and check if they are the same
# - Create a `for loop` to print the wkt and length attributes of every ring in _holes_

# %%
# Create and display the polygon here

# %%
# print attributes here

# %% [markdown]
# ### 5. get_area() function
# Create a function **get_area()** accepting one parameter **polygon**. The function should accept a `shapely.geometry.Polygon` and return its area.
# - Inside the function, check that the input is a shapely.geometry.Polygon object (hint: use .geom_type attribute). If the argument is anything else, print an error message: "Input should be a shapely.geometry.Polygon".
# - Test and demonstrate the usage of the function using the polygon defined in Q3 as input.

# %%
# Add your code here

# %% [markdown]
# ### 6. get_length() function
# Create a function **get_length()** accepting one parameter **geometry**. The function should accept either a `shapely.geometry.LineString` or a `shapely.geometry.Polygon` as input.
# - Inside the function, check the type of the input and return the length of the line if input is a LineString and length of the exterior ring if the input is a Polygon. If something else is passed to the function, print an error message "‘geometry’ should be either a LineString or a Polygon".
# - Test and demonstrate the usage of the function using the linestring defined in Q2 as input.
# - Test and demonstrate the usage of the function using the polygon defined in Q4 as input.

# %%
# Add your code here

# %%
# call the function on poly2
