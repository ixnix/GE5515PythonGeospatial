# %% [markdown]
# # Assignment 2: Shapely Geometry Objects
#
# In this assignment, you will create and manipulate shapely geometry objects (Point, LineString, Polygon) and write reusable functions.
#
# **Submission:** Submit your completed `.ipynb` notebook file with all code cells executed and outputs visible.

# %% [markdown]
# ### 1. Point geometry
#
# - Create a shapely point object `point1` with coordinates (0, 1)
# - Print the following attributes of `point1`: `wkt`, `geom_type`, `coords` (convert to list), `x`, `y`
# - Create another point `point2` with coordinates (0, 5)
# - Calculate the distance between `point1` and `point2`
# - Create a circle `cir1` with radius 2, centered at `point1`, using the [`.buffer()` method](https://shapely.readthedocs.io/en/2.0.6/reference/shapely.Point.html)
# - Print the `wkt` attribute of `cir1`
#
# **Hint:** Import `Point` from `shapely.geometry`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 2. LineString geometry
#
# - Create a shapely LineString object `line1` using `point1` and `point2` from Q1
# - Print the following attributes of `line1`: `wkt`, `geom_type`, `coords` (convert to list), `xy`, `length`, `centroid`
#
# **Hint:** Import `LineString` from `shapely.geometry`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 3. Polygon geometry
#
# - Create a pentagon `poly1` using coordinates: `(30, 2.01), (31.91, 0.62), (31.18, -1.63), (28.82, -1.63), (28.09, 0.62)`
# - Print the following attributes: `wkt`, `geom_type`, `area`, `bounds`, `centroid`, `exterior`, `exterior.length`
#
# **Hint:** Import `Polygon` from `shapely.geometry`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 4. Polygon with holes
#
# - The `bounds` attribute returns a tuple of (minx, miny, maxx, maxy).
# - Create a polygon `poly2` using the bounds of `poly1` as the exterior ring and `poly1` itself as the interior ring (hole).
# - Print: `wkt`, `geom_type`, `area`, `bounds`, `centroid`, `exterior`, `exterior.length`, `interiors` (name the output `holes`)
# - Compare `area`, `bounds`, and `centroid` with those of `poly1` — are they the same?
# - Create a `for` loop to print the `wkt` and `length` of every ring in `holes`
#
# **Hint:** `Polygon(exterior_coords, [hole_coords])` — the second argument is a list of interior rings.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 5. `get_area()` function
#
# Create a function `get_area()` that accepts one parameter `polygon`.
#
# - The function should accept a `shapely.geometry.Polygon` and return its area.
# - Inside the function, check that the input is a Polygon (use `.geom_type`). If not, print: `"Input should be a shapely.geometry.Polygon"`
# - Test the function using the polygon from Q3.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 6. `get_length()` function
#
# Create a function `get_length()` that accepts one parameter `geometry`.
#
# - If the input is a `LineString`, return its `.length`.
# - If the input is a `Polygon`, return its `.exterior.length`.
# - For any other type, print: `"'geometry' should be either a LineString or a Polygon"`
# - Test the function with the LineString from Q2 and the Polygon from Q4.
#
# **Hint:** Use `.geom_type` to check the input type inside the function.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Summary
#
# In this assignment, you practiced:
# - Creating `Point`, `LineString`, and `Polygon` geometry objects with shapely
# - Accessing geometry attributes (`wkt`, `area`, `length`, `bounds`, `centroid`)
# - Creating polygons with holes (interior rings)
# - Writing reusable functions with input type checking
#
# **Don't forget to save your notebook before submitting!**
