# %% [markdown]
# # Assignment 12: Spatiotemporal Analysis with xarray
#
# In this assignment, you will use xarray to practice spatiotemporal selection and slicing, perform statistical aggregations, and analyze time series and visualize trends.
#
# **Data file:** `data/cru_tmp_1951_2024.nc` (CRU monthly temperature dataset)
#
# **Submission:** Submit your completed `.ipynb` notebook file with all code cells executed and outputs visible.
#
# ---

# %% [markdown]
# ### (a) Data Exploration
#
# - Load the CRU monthly temperature dataset `data/cru_tmp_1951_2024.nc` into an xarray Dataset. Name it `ds`.
# - Print the dimensions and coordinates.
#
# **Hint:** `ds = xr.open_dataset('data/cru_tmp_1951_2024.nc')`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (b) Plot a temperature map
#
# - Plot a global map of temperature for **January 2000**.
#
# **Hint:** `ds['tmp'].sel(time='2000-01').plot()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (c) Spatial Data Selection
#
# - Select temperature data for **North America** (lat: 15°N–75°N, lon: 170°W–50°W). Save as `na_tmp`.
# - Plot the selected region's temperature map for **July 2010**.
#
# **Hint:** `na_tmp = ds['tmp'].sel(lat=slice(75, 15), lon=slice(-170, -50))`
# Note: Latitude slicing order depends on whether your latitude coordinates are ascending or descending.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (d) Temporal Data Selection
#
# - Select temperature data for **1981–2010** (a standard climate normal period).
# - Calculate the global **annual mean** temperature time series. Save as `tmp_ts`.
# - Plot as a dotted line.
#
# **Hint:** `ds['tmp'].sel(time=slice('1981', '2010')).groupby('time.year').mean()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (e) Statistical Aggregation
#
# - Compute the climatological **seasonal mean** temperatures (DJF, MAM, JJA, SON) for 1981–2010 globally. Save as `seasonal_tmp`.
# - Make a **2×2 subplot** to show the seasonal means. Use `turbo` colormap, `vmin=-30`, `vmax=30`.
# - Briefly discuss the spatial patterns in each season (1–2 sentences).
#
# **Hint:** `.groupby('time.season').mean()` gives you seasonal averages. Access seasons with `.sel(season='DJF')`, etc.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (f) Regional Time Series and Trends
#
# - Extract monthly temperature data averaged over **Europe** (lat: 35°N–70°N, lon: 10°W–40°E) from 1951 to 2024. Save as `eu_tmp`.
# - Calculate and plot the **annual mean** temperature time series for this region.
#
# **Hint:** First select the spatial region with `.sel()`, then compute the spatial mean with `.mean(dim=['lat', 'lon'])`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (g) Monthly Temperature Cycle
#
# - Select temperature data for the **Amazon Basin** (lat: 15°S–5°N, lon: 75°W–50°W) for 1991–2020. Save as `amazon_tmp`.
# - Calculate and plot a **bar chart** of the monthly climatological mean temperature (average for each month across all 30 years).
# - Explain the pattern you observe (1–2 sentences).
#
# **Hint:** `.groupby('time.month').mean()` gives monthly climatology. Use `.plot.bar()` for bar chart.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (h) Spatial Anomaly Calculation
#
# - Compute the global mean temperature from **1981–2000** as your climatology baseline. Name it `climatology`.
# - Calculate the annual temperature anomaly for **2010** (2010 annual mean minus climatology). Name it `anomaly`.
# - Plot the global anomaly map and briefly describe notable patterns (regions of warming or cooling).
#
# **Hint:** `climatology = ds['tmp'].sel(time=slice('1981','2000')).mean(dim='time')`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (i) Extreme Temperature Events
#
# - Calculate the global mean temperature for **July** from 1981–2000. Save as `climatology_ts`.
# - Calculate the mean and standard deviation of `climatology_ts`. Save as `cmean` and `cstd`. Print them.
# - Identify July months between **2001–2024** where global mean temperature exceeds `cmean + 2*cstd`.
# - List the identified extreme months.
#
# **Hint:** Select July data with `.sel(time=ds.time.dt.month==7)`. Use `.where()` to filter extreme values.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Summary
#
# In this assignment, you practiced:
# - Loading and exploring NetCDF climate data with xarray
# - Spatial and temporal selection/slicing
# - Computing seasonal and annual climatologies
# - Calculating temperature anomalies
# - Identifying extreme events using statistical thresholds
#
# **Don't forget to save your notebook before submitting!**
