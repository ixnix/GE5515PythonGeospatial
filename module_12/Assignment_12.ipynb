# %% [markdown]
# In this assignment you will use xarray to practice spatiotemporal selection and slicing, perform statistical aggregations, and analyze time series and visualize trends.

# %% [markdown]
# ### (a) Data Exploration (5 points)
#
# - Load the CRU monthly temperature dataset `cru_tmp_1951_2024.nc` into an xarray Dataset. Name as `ds`.
# - Print the dimensions and coordinates.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (b) Plot a temperature map  (5 points)
# - Plot a global map of temperature for January 2000.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (c) Spatial Data Selection  (10 points)
# - Select temperature data for North America (lat: 15°N–75°N, lon: 170°W–50°W). Save as `na_tmp`.
# - Plot the selected region's temperature map for July 2010.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (d) Temporal Data Selection  (10 points)
# - Select temperature data for the period 1981–2010 (a common climate normal period).
# - Calculate the global annual mean temperature time series for this period. Save as `tmp_ts`.
# - Hint: annual mean can be calculated using .groupby('time.year').mean()
# - Plot the global annual mean temperature as a dotted line.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (e) Statistical Aggregation  (15 points)
# - Compute the climatological seasonal mean temperatures (DJF, MAM, JJA, SON) for 1981–2010 globally. Save as `seasonal_tmp`.
# - Make a 2x2 subplot to plot the seasonal mean temperatures. Use `turbo` cmap, vmin=-30, vmax=30 for all panels.
# - Briefly discuss the spatial patterns you observe in each season.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (f) Regional Time Series and Trends (10 points)
# - Extract monthly temperature data averaged over Europe (lat: 35°N–70°N, lon: 10°W–40°E) from 1950 to 2020. Save as `eu_tmp`.
# - Calculate and plot the annual mean temperature time series for this region.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (g) Monthly Temperature Cycle (15 points)
# - Select temperature data for the Amazon Basin (lat: 15°S–5°N, lon: 75°W–50°W) over the period 1991–2020. Save as `amazon_tmp`.
# - Calculate and plot a bar chart of the monthly climatological mean temperature (mean for each month across all 30 years).
# - Explain the pattern you observe.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (h) Spatial Anomaly Calculation (15 points)
# - Compute the global mean temperature from 1981–2000 as your climatology baseline. Name it `climatology`.
# - Calculate the annual temperature anomaly for 2010 (i.e., 2010 annual mean minus the climatology). Name it `anomaly`.
# - Plot the global map of the anomaly and briefly describe notable spatial patterns (regions of warming or cooling).

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (i) Extreme Temperature Events (15 points)
# - Calculate the global mean temperature for July from 1981 to 2000. Save it as `climatology_ts`.
# - Hint: use .sel(time=ds.time.dt.month==7) to select July month.
# - Calculate the mean and standard deviation of `climatology_ts`. Save the results as `cmean` and `cstd`. Print them out.
# - Identify July months between 2001–2024 where the global mean temperature exceeds `cmean+2*cstd`. Hint: use `.where()`.
# - List the identified extreme months.

# %%
# ADD YOUR OWN CODE HERE
