# %% [markdown]
# # Assignment 10: Raster Data with xarray
#
# In this assignment, you will practice reading, indexing, slicing, and clipping raster elevation data using xarray and rioxarray.
#
# **Data files:**
# - `data/n47_w089_1arc_v3.tif` (DEM from lecture)
# - `data/upper_peninsula_county.gpkg` (county boundaries)
# - DEM tile downloaded from USGS National Map (see Problem 2)
#
# **Submission:** Submit your completed `.ipynb` notebook file with all code cells executed and outputs visible.

# %% [markdown]
# ### 1. Selecting raster data
#
# You will use the DEM data (`data/n47_w089_1arc_v3.tif`) from the lecture to practice indexing, slicing, and basic calculations.

# %% [markdown]
# #### (a) Read the data
#
# Read the file as an xarray Dataset called `elevation`.
#
# **Hint:** Use `import rioxarray; elevation = rioxarray.open_rasterio('data/n47_w089_1arc_v3.tif')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (b) Print attributes
#
# Print the three attributes of `elevation`: data variables (`data_vars`), dimensions (`dims`), and coordinates (`coords`).

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Rename variable
#
# Rename the elevation variable to `'elv'`.
#
# **Hint:** `.rename({'old_name': 'elv'})`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (d) Index selection
#
# Find the elevation value at **integer index positions** x=100, y=200.
#
# **Hint:** Use `.isel(x=100, y=200)` for integer-based indexing.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (e) Slice and average
#
# Find the average elevation between **integer index positions** x=1000 to 2000, y=2000 to 3000.
#
# **Hint:** Use `.isel(x=slice(1000, 2000), y=slice(2000, 3000)).mean()`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (f) Conditional selection
#
# Find the average elevation for pixels with elevation values **between 300 and 400 m**.
#
# **Hint:** Use `.where()` with a boolean condition:
# ```python
# mask = (elevation['elv'] >= 300) & (elevation['elv'] <= 400)
# elevation['elv'].where(mask).mean()
# ```

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 2. Clipping raster data

# %% [markdown]
# #### (a) Download DEM tile
#
# Go to https://apps.nationalmap.gov/downloader/ and use **Point Search** to download the 1×1 degree DEM tile covering the MTU campus.
#
# **Steps:**
# 1. Search for coordinates near Houghton, MI (approximately 47.12°N, 88.55°W)
# 2. Select "Elevation Products (3DEP)" → 1 arc-second DEM
# 3. Download the `.tif` file (name will be similar to `USGS_1_n48w089_YYYYMMDD.tif`)
# 4. Save to your `data/` folder
#
# **Note:** The filename includes a date stamp that may differ from examples. This file is not provided — you must download it yourself.

# %% [markdown]
# #### (b) Read the new file
#
# Read the downloaded file as an xarray Dataset called `data`.
#
# **Hint:** `data = rioxarray.open_rasterio('data/USGS_1_n48w089_YYYYMMDD.tif')` — use your actual filename.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Clip to Houghton County
#
# - Load `data/upper_peninsula_county.gpkg` and filter for Houghton County.
# - Make sure the clip layer has the **same CRS** as the elevation data.
# - Clip the elevation data and name the output `data_houghton`.
#
# **Hint:** Use `.rio.clip(geometries)` where `geometries` is the geometry column of your filtered county GeoDataFrame.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (d) Create elevation map
#
# - Plot the elevation of Houghton County using the `terrain` colormap.
# - Add a title: "Elevation of Houghton County".
#
# **Hint:** `data_houghton.plot(cmap='terrain'); plt.title('Elevation of Houghton County')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (e) Find min/max elevation
#
# Find and print the lowest and highest elevation values in Houghton County.
#
# **Hint:** `.min().values` and `.max().values`

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Summary
#
# In this assignment, you practiced:
# - Reading raster data with `rioxarray`
# - Integer-based indexing (`.isel()`) and conditional selection (`.where()`)
# - Downloading DEM data from USGS National Map
# - Clipping raster data to a vector boundary (`.rio.clip()`)
# - Visualizing elevation data with colormaps
#
# **Don't forget to save your notebook before submitting!**
