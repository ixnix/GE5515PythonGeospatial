# %% [markdown]
# ### 1. Selecting raster data
#
# You will use the DEM data (`n47_w089_1arc_v3.tif`) from the lecture to practice data selection (indexing and slicing) and basic calculations.

# %% [markdown]
# #### (a)
# Read in the file as a xarray dataset, `elevation`.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (b)
# Print out the three attributes of `elevation`: data variables (data_vars), dimensions (dims), and coordinates (coords).

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (c)
# Rename the elevation variable name to 'elv'.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (d)
# Find the elevation value at the index positions x=100, y=200.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (e)
# Find the average elevation value between index positions x=1000 to 2000, y=2000 to 3000.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (f)
# Find the average elevation value of the elevation range between 300 and 400 m.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### 2. Clipping raster data

# %% [markdown]
# #### (a)
# Go to https://apps.nationalmap.gov/downloader/, and use Point Search to download the 1x1 degree DEM data tile covering the MTU campus. The file name will be `USGS_1_n48w089_20240205.tif`. Save to your data/ folder. Note that this file will not be directly provided to you.

# %% [markdown]
# #### (b)
# Read in the new file as a xarray dataset, `data`.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (c)
# Use the `upper_peninsula_county.gpkg` to clip the elevation data for Houghton County. Make sure your clip layer has the same projection as the elevation data. Name the output `data_houghton`.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (d)
# Create a map to show the elevation of Houghton county. Use `terrain` colormap. Add a title 'Elevation of Houghton County'.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (e)
# Find the lowest and highest elevation values of the Houghton County.

# %%
# ADD YOUR OWN CODE HERE
