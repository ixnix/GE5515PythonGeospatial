# %% [markdown]
# # Assignment 5: Geocoding and Spatial Data I/O
#
# In this assignment, you will geocode addresses, reproject data, and save results as GeoPackage files.
#
# **Data file:** `Michigan_county_seats.txt` (in your `data/` folder)
#
# **Submission:** Submit your completed `.ipynb` notebook file with all code cells executed and outputs visible.

# %% [markdown]
# ### 1. Geocode Michigan county seats
#
# #### (a) Read the input file
#
# Read `data/Michigan_county_seats.txt` into a `pandas.DataFrame` called `county_seats`. The text file is **semicolon-separated** (`;`) and includes:
# - `id` (integer) — a unique identifier for each county seat
# - `name` (string) — name of the county seat
# - `addr` (string) — the address
#
# **Hint:** `pd.read_csv('data/Michigan_county_seats.txt', sep=';')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (b) Geocode the addresses
#
# - Geocode the addresses using the **Nominatim** geocoding service.
# - Join the results with the input DataFrame and store in a `geopandas.GeoDataFrame` called `county_seats`.
#
# **Hint:** Use `gpd.tools.geocode(county_seats['addr'], provider='nominatim', user_agent='GE5515')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Reproject to Michigan Oblique Mercator
#
# Reproject `county_seats` to EPSG:3078 (Michigan Oblique Mercator).
#
# **Hint:** `county_seats = county_seats.to_crs(epsg=3078)`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (d) Save the result
#
# Save `county_seats` as a GeoPackage named `data/Michigan_county_seats.gpkg`.
#
# **Hint:** `.to_file('data/Michigan_county_seats.gpkg', driver='GPKG')`

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Summary
#
# In this assignment, you practiced:
# - Reading delimited text files into pandas DataFrames
# - Geocoding addresses to obtain point geometries
# - Reprojecting data to a regional CRS
# - Saving geospatial data in GeoPackage format
#
# **Don't forget to save your notebook before submitting!**
