# %% [markdown]
# ### 1. Geocode
#
# In this problem you will translate the locations of Michigan county seats into coordinates.
#
# #### (a) Read an input file containing the addresses of 10 county seats
#
# Read in the data file `Michigan_county_seats.txt` into a pandas.DataFrame called `county_seats`. The text file is in semicolon-separated format (`;`) and includes the following columns:
# - `id` (integer) a unique identifier for each county seat
# - `name` (string) of each county seat
# - `addr` (string) the address

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (b) Geocode the addresses
#
# - Geocode the addresses using the Nominatim geocoding service.
# - Join the results with the input **pandas DataFrame**, and store them in a **geopandas.GeoDataFrame** with the same name (`county_seats`).

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (c) Reproject to Michigan Oblique Mercator (EPSG=3078)

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (d) Save the resulting vector data set
#
# Save `county_seats` as a *GeoPackage* named `Michigan_county_seats.gpkg`:

# %%
# ADD YOUR OWN CODE HERE
