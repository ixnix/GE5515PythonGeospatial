# %% [markdown]
# In this assignment you will practice using PM2.5 raster data and U.S. county vector data to perform PM2.5 exposure analysis. 10 points for each question.

# %% [markdown]
# ### (a) Use rioxarray to read the 1-km PM2.5 raster file. Output the dataset’s CRS, resolution, and shape.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (b) Use geopandas to load the U.S. counties shapefile. Print the total number of counties.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (c) Check if the raster and vector datasets have matching CRS. If not, reproject the raster using .rio.reproject() to match the county shapefile’s CRS.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (d) Filter counties to include only Michigan, Wisconsin, Illinois, Indiana, and Ohio.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (e) Use rasterstats.zonal_stats() to compute mean PM2.5 concentration for counties in the selected region.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (f) Find the county in each state with the highest PM2.5.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (g) For each county, compute pm25_mean * population and store it in a new column. Then compute the overall population-weighted PM2.5 for the selected states.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (h) Group the results by STATE_NAME and compute:
# - Total population per state
# - Average PM2.5 per state (simple mean)
# - Population-weighted PM2.5 per state

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (i) Create a choropleth map showing pm25_mean for counties in the selected region. Set vmax to 250. Add a colorbar, legend, and title.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### (j) Create a horizontal bar plot showing population-weighted PM2.5 for each state. Sort the bars from highest to lowest.

# %%
# ADD YOUR OWN CODE HERE
