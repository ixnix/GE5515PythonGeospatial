# %% [markdown]
# # Assignment 13: Zonal Statistics — PM2.5 Exposure Analysis
#
# In this assignment, you will combine PM2.5 raster data with U.S. county vector data to perform an air quality exposure analysis.
#
# **Data files:**
# - PM2.5 raster file (in your `data/` folder)
# - U.S. counties shapefile (in your `data/` folder)
#
# **Submission:** Submit your completed `.ipynb` notebook file with all code cells executed and outputs visible.
#
# ---

# %% [markdown]
# ### (a) Read raster data
#
# Use `rioxarray` to read the 1-km PM2.5 raster file. Print the dataset's **CRS**, **resolution**, and **shape**.
#
# **Hint:** `import rioxarray; pm25 = rioxarray.open_rasterio('data/your_pm25_file.tif')`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (b) Load vector data
#
# Use `geopandas` to load the U.S. counties shapefile. Print the **total number of counties**.
#
# **Hint:** `counties = gpd.read_file('data/your_counties_file.shp'); print(len(counties))`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (c) Check and match CRS
#
# Check if the raster and vector datasets have matching CRS. If not, reproject the raster using `.rio.reproject()` to match the county shapefile's CRS.
#
# **Hint:** `pm25 = pm25.rio.reproject(counties.crs)`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (d) Filter to Great Lakes states
#
# Filter counties to include only **Michigan, Wisconsin, Illinois, Indiana, and Ohio**.
#
# **Hint:** `states = ['Michigan', 'Wisconsin', 'Illinois', 'Indiana', 'Ohio']`
# `selected = counties[counties['STATE_NAME'].isin(states)]`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (e) Compute zonal statistics
#
# Use `rasterstats.zonal_stats()` to compute the **mean PM2.5 concentration** for each county in the selected region.
#
# **Hint:**
# ```python
# from rasterstats import zonal_stats
# stats = zonal_stats(selected, 'data/your_pm25_file.tif', stats='mean')
# ```

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (f) Highest PM2.5 by state
#
# Find the county in **each state** with the highest PM2.5.
#
# **Hint:** Use `.groupby('STATE_NAME')` and then `.idxmax()` or `.sort_values().groupby().first()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (g) Population-weighted PM2.5
#
# - For each county, compute `pm25_mean × population` and store in a new column.
# - Compute the overall **population-weighted PM2.5** for the selected states.
#
# **Formula:** Population-weighted PM2.5 = Σ(PM2.5 × population) / Σ(population)
#
# **Hint:** `weighted_pm25 = (selected['pm25_mean'] * selected['population']).sum() / selected['population'].sum()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (h) Group by state
#
# Group the results by `STATE_NAME` and compute:
# - Total population per state
# - Average PM2.5 per state (simple mean)
# - Population-weighted PM2.5 per state
#
# **Hint:** Use `.groupby('STATE_NAME').agg(...)` with appropriate aggregation functions.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (i) Choropleth map
#
# Create a choropleth map showing `pm25_mean` for counties in the selected region.
# - Set `vmax=250`
# - Add a colorbar, legend, and title.
#
# **Hint:** `selected.plot(column='pm25_mean', legend=True, vmax=250)`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### (j) Bar plot
#
# Create a **horizontal bar plot** showing population-weighted PM2.5 for each state. Sort the bars from highest to lowest.
#
# **Hint:** Use `.sort_values().plot.barh()` on your grouped results.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Summary
#
# In this assignment, you practiced:
# - Reading and reprojecting raster data
# - Computing zonal statistics with `rasterstats`
# - Calculating population-weighted exposure metrics
# - Grouping and aggregating spatial data by state
# - Creating choropleth maps and bar plots
#
# **Don't forget to save your notebook before submitting!**
