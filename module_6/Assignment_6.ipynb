# %% [markdown]
# ### 1. Create buffers around county seats

# %% [markdown]
# #### (a) Load the Michigan county seats dataset
#
# - Load the `Michigan_county_seats.gpkg` dataset from the previous module into a geopandas GeoDataFrame called `county_seats`.
# - Print out the first few rows using `.head()`.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (b) Create a *buffer* around the points
#
# - Calculate a 10 km buffer for each geocoded point. Overwrite the `geometry` column with the new buffer geometry. Use the [`geopandas.GeoDataFrame.buffer()` method](http://geopandas.org/geometric_manipulations.html#GeoSeries.buffer) which implements shapely’s [`buffer()`](http://toblerity.org/shapely/manual.html#object.buffer) in the background. You only need to specify the `distance` parameter, don’t worry about other arguments.
# - Print out the first few rows using `.head()`. You should see that the geometry column has changed from POINT to POLYGON.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (c) Save buffer geometry layer
#
# Save the data frame containing the buffer geometries into a new layer `buffers` to a new file `Michigan_county_seats_buffer.gpkg`:

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# ### 2. How many people live near county seats?
#
# In the last step, use a *spatial join* to relate population data to the buffer layer created above to find out how many people live in all census tracts **within** 10 km distance from each county seat.

# %% [markdown]
# #### (a) Load the buffer geometries
#
# - Load the `Michigan_county_seats_buffer.gpkg` file into a geopandas GeoDataFrame called `county_seats_buffer`.
# - Print out the first few rows using `.head()`.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (b) Load the population data
#
# - Read in the Michigan socioeconomic data as a geopandas GeoDataFrame, `social`.
# - Multiply the `PopDenMiSq` and `ALANDSQMi` columns to calculate the total population as a new column `TotPop`.
# - Extract the `TotPop` and geometry columns as a GeoDataFrame `population`.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (c) Check whether the two GeoDataFrames are in the same CRS.
# - Test if the crs of `population` and `county_seats_buffer` are the same.
# - If their projections are the same, you do NOT need to do anything.
# - If their projections are different, reproject `population` onto the same projection of `county_seats_buffer`.

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (d) Carry out a *spatial join* between the `population` and the `county_seats_buffer`
#
# - Join the county seats buffers with the population data, for all census tracts that are **within** the buffer area of each county seat.
# - Use a join-type that retains only rows from both input data frames for which the geometric predicate is true. [see join types here](https://geopandas.org/en/stable/gallery/spatial_joins.html#Types-of-spatial-joins).

# %%
# ADD YOUR OWN CODE HERE

# %% [markdown]
# #### (e) Compute the population sum around county seats
#
# - Group the resulting (joint) data frame by county seat (`id` or `name`), and calculate the `sum()` of the population living inside the 10 km radius around them.
# - Print the results in the form "X people live within the 10 km radius from Y".

# %%
# ADD YOUR OWN CODE HERE
