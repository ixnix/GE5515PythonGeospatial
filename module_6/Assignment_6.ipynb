# %% [markdown]
# # Assignment 6: Spatial Join and Buffer Analysis
#
# In this assignment, you will create buffers around Michigan county seats and use spatial joins to estimate how many people live near each county seat.
#
# **Data files:**
# - `data/Michigan_county_seats.gpkg` (from Assignment 5)
# - `data/MI_socioeconomic.gpkg` (Michigan socioeconomic data with census tract boundaries)
#
# **Submission:** Submit your completed `.ipynb` notebook file with all code cells executed and outputs visible.

# %% [markdown]
# ### 1. Create buffers around county seats

# %% [markdown]
# #### (a) Load the data
#
# - Load `data/Michigan_county_seats.gpkg` into a GeoDataFrame called `county_seats`.
# - Print the first few rows using `.head()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (b) Create a buffer around the points
#
# - Calculate a **10 km buffer** for each geocoded point. Overwrite the `geometry` column with the new buffer geometry.
# - Use the [`geopandas.GeoDataFrame.buffer()` method](http://geopandas.org/geometric_manipulations.html#GeoSeries.buffer). You only need to specify the `distance` parameter (10000 m).
# - Print `.head()`. The geometry column should now show POLYGON instead of POINT.
#
# **Hint:** `county_seats['geometry'] = county_seats.geometry.buffer(10000)`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Save buffer geometry layer
#
# Save the data frame containing the buffer geometries as `data/Michigan_county_seats_buffer.gpkg`:
#
# **Hint:** `.to_file('data/Michigan_county_seats_buffer.gpkg', driver='GPKG')`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 2. How many people live near county seats?
#
# Use a **spatial join** to relate population data to the buffer layer to find how many people live in census tracts **within** 10 km of each county seat.

# %% [markdown]
# #### (a) Load the buffer geometries
#
# - Load `data/Michigan_county_seats_buffer.gpkg` into a GeoDataFrame called `county_seats_buffer`.
# - Print `.head()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (b) Load the population data
#
# - Read `data/MI_socioeconomic.gpkg` as a GeoDataFrame `social`.
# - Multiply the `PopDenMiSq` and `ALANDSQMi` columns to calculate total population as a new column `TotPop`.
# - Extract the `TotPop` and `geometry` columns as a GeoDataFrame `population`.
#
# **Hint:** `population = social[['TotPop', 'geometry']].copy()`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (c) Check CRS match
#
# - Test if `population` and `county_seats_buffer` have the same CRS.
# - If different, reproject `population` to match `county_seats_buffer`.
#
# **Hint:** `population.crs == county_seats_buffer.crs`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (d) Spatial join
#
# - Join the county seats buffers with the population data for all census tracts that are **within** the buffer area.
# - Use a join type that retains only matching rows from both datasets. [See spatial join types](https://geopandas.org/en/stable/gallery/spatial_joins.html#Types-of-spatial-joins).
#
# **Hint:** `gpd.sjoin(population, county_seats_buffer, how='inner', predicate='within')`

# %%
# YOUR CODE HERE

# %% [markdown]
# #### (e) Compute population sum
#
# - Group the joined data by county seat `name`, and calculate the `sum()` of `TotPop`.
# - Print: "X people live within the 10 km radius from Y" for each county seat.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Summary
#
# In this assignment, you practiced:
# - Creating buffer zones around point features
# - Saving and loading GeoPackage files
# - Checking and matching CRS between datasets
# - Performing spatial joins to combine vector datasets
# - Aggregating population data by spatial proximity
#
# **Don't forget to save your notebook before submitting!**
