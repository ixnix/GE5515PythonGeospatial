# %% [markdown]
# # Assignment 1: Exploring Weather Data with Pandas
#
# In this assignment, you will use pandas to explore and analyze NOAA daily weather data from Houghton and Marquette.
#
# **Data files:** `GHCNd_Houghton.csv` and `GHCNd_Marquette.csv` (in your `data/` folder)
#
# **Submission:** Submit your completed `.ipynb` notebook file with all code cells executed and outputs visible.

# %% [markdown]
# ### 1. Load the Houghton weather data
#
# - Import the `pandas` module.
# - Use `.read_csv()` to read the `GHCNd_Houghton.csv` file into a DataFrame called `dfH`.
# - Within `.read_csv()`, skip the header lines, parse the `DATE` column as a datetime object and set it as the DatetimeIndex, and only read in these columns: `DATE`, `PRCP`, `TMAX`, `TMIN`, `SNOW`.
# - **Hint:** use the following arguments in `.read_csv()`: `skiprows`, `parse_dates`, `index_col`, `usecols`.
# - Print the first 5 rows of `dfH`.

# %% [markdown]
# ### 1. Let's first look at the Houghton weather data.
#
# - Import the pandas module.
# - Use `.read_csv()` to read the `GHCNd_Houghton.csv` file into a DataFrame called `dfH`.
# - Within .read_csv(), skip the header lines, parse the `DATE` column as datetime object and set it as the DatetimeIndex, and only read in these columns: `DATE`,`PRCP`,`TMAX`,`TMIN`,`SNOW`. Hint: use the following arguments in `.read_csv()`: `skiprows`, `parse_dates`, `index_col`, `usecols`.
# - Print the first 5 rows of `dfH`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 2. Data characteristics
# Based on the `dfH` DataFrame, write appropriate codes to answer the following questions:
#
# - How many rows are there in the data? *(Hint: use `len()` or `.shape`)*
# - What is the shape of the DataFrame?
# - What are the column names?
# - What are the data types of the columns? *(Hint: use `.dtypes`)*

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 3. Descriptive Statistics
#
# Based on the `dfH` DataFrame, write appropriate codes to answer the following questions:
#
# - What is the mean value of Maximum Temperature (use the `TMAX` column)?
# - What is the standard deviation of the Maximum Temperature?
# - What is the lowest temperature ever observed (use the `TMIN` column)?
# - What is the highest daily snowfall ever observed?
# **Hint:** Use `.mean()`, `.std()`, `.min()`, `.max()` methods on individual columns.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 4. Precipitation analysis
#
# Let's look at the precipitation `PRCP`. The unit is mm.
#
# - What is the highest daily total rainfall ever observed in Houghton? Name it `Pmax`.
# - On what day did it happen? Does your result match the 2018 Father's Day Flood event? *(Hint: use `.idxmax()`)*
# - To evaluate how extreme the event was, calculate the z-score:
#     - Calculate the `PRCP` climatological mean as `Pavg`
#     - Calculate the `PRCP` standard deviation as `Pstd`
#     - Calculate `(Pmax - Pavg) / Pstd` — this is the **z-score**. Extreme z-score values (e.g., > 3) indicate extremely rare occurrence.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 5. Snowfall analysis
#
# Let's look at the snowfall data in the `SNOW` column. The unit is mm.
#
# - Create a new column `SNOW_IN` by converting snowfall from mm to inches (1 inch = 25.4 mm).
# - What is the highest daily snowfall ever recorded (in inches)?
# - Remove missing values from `SNOW_IN` using `.dropna()`. How many rows are there **before and after** removing missing values?
# - Calculate the number of days in each year with snowfall observations. *(Hint: use `.resample('YE').count()`)*
# - Use `.resample('YE')` to calculate the **total snowfall** for each year.
# - Which year has the most snowfall, and how much was it? *(Hint: use `.idxmax()`)*
# - Create a marker line plot for the annual total snowfall.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 6. Comparing Houghton and Marquette snowfall
#
# - Use `.read_csv()` to read `GHCNd_Marquette.csv` as `dfM`. Adjust `skiprows` and `usecols` as needed.
# - Add a new column `SNOW_IN` by converting snowfall from mm to inches.
# - Slice the `SNOW_IN` data for **1991–2000** from both `dfH` and `dfM`.
# - Calculate the number of days on which snowfall in Marquette is higher than Houghton.
# - Find the date on which the snowfall difference between Houghton and Marquette is the largest. Print the snowfall of both cities on that day.
# - Calculate the annual total snowfall from both cities and make a marker line plot with **different colors** and a **legend**.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 7. Comparing temperature records
#
# - Slice the `TMAX` data for **1991–2020** from both `dfH` and `dfM`.
# - Calculate the `TMAX` difference between the two cities. *(This works because both Series share a DatetimeIndex.)*
# - Calculate the number of days in each year on which the temperature in Marquette is above 20°C **and** at least five degrees above Houghton.
# - Make a **bar plot** to show your result.
# - Calculate the number of days in each year on which the temperature in Houghton is below 0°C **and** at least five degrees below Marquette.
# - Make a **bar plot** to show your result.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Summary
#
# In this assignment, you practiced:
# - Reading CSV files with `pandas` and parsing dates
# - Exploring DataFrame structure (shape, dtypes, head)
# - Computing descriptive statistics (mean, std, min, max)
# - Time series slicing, resampling, and comparison
# - Creating line plots and bar plots for data visualization
#
# **Don't forget to save your notebook before submitting!**
