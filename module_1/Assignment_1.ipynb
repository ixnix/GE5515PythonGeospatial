# %% [markdown]
# In this assignment, you will use pandas to explore and analyze the NOAA daily weather data from Houghton and Marquette.

# %% [markdown]
# ### 1. Let's first look at the Houghton weather data.
#
# - Import the pandas module.
# - Use `.read_csv()` to read the `GHCNd_Houghton.csv` file into a DataFrame called `dfH`.
# - Within .read_csv(), skip the header lines, parse the `DATE` column as datetime object and set it as the DatetimeIndex, and only read in these columns: `DATE`,`PRCP`,`TMAX`,`TMIN`,`SNOW`. Hint: use the following arguments in `.read_csv()`: `skiprows`, `parse_dates`, `index_col`, `usecols`.
# - Print the first 5 rows of `dfH`.

# %%
# Type your codes here

# %% [markdown]
# ### 2. Based on the `dfH` DataFrame, write appropriate codes to answer the following questions about the data characteristics:
#
# - How many rows are there in the data?
# - What is the shape of the DataFrame?
# - What are the column names?
# - What are the data types of the columns?

# %%
# Type your codes here

# %% [markdown]
# ### 3. Based on the `dfH` DataFrame, write appropriate codes to answer the following questions about the Descriptive Statistics:
#
# - What is the mean value of Maximum Temperature (use the `TMAX` column)?
# - What is the standard deviation of the Maximum Temperature?
# - What is the lowest temperature ever observed (use the `TMIN` column)?
# - What is the highest daily snowfall ever observed?

# %%
# Type your codes here

# %% [markdown]
# ### 4. Let's look at the precipitation `PRCP`. The unit is mm.
# - What is the highest daily total rainfall ever observed in Houghton? Name it `Pmax`.
# - On what day did it happen? Does your result match the 2018 Father's Day Flood event? Hint: use `.idxmax()`.
# - To evaluate how extreme the event was, we can calculate the number of standard deviations of `Pmax` above the climatological average, as follows:
#     - Calculate the `PRCP` climatological mean as `Pavg`
#     - Calculate the `PRCP` standard deviation as `Pstd`
#     - Calculate the ratio of `Pmax - Pavg` to `Pstd`. This is called z-score. Extreme z-score values indicate extremely rare occurrence.

# %%
# Type your codes here

# %% [markdown]
# ### 5. Let's look at the snowfall data in the `SNOW` column. The unit is mm.
# - Create a new column in the DataFrame called `SNOW_IN` by converting the snowfall from mm to inches. We will use `SNOW_IN` in the following analysis.
# - What is the highest daily snowfall ever recorded (in inches)?
# - There are many missing values in the snowfall record. Remove those missing values using `.dropna()`.
# - How many rows are there in the 'SNOW' column **before and after** removing the missing values?
# - Calculate the number of days in each year with snowfall observations. This will give you a rough idea about the data completeness.
# - Use `.resample()` to calculate the total snowfall for each year.
# - Which year has the most snowfall, and how much was it?
# - Create a marker line plot for the annual total snowfall.

# %%
# Type your codes here

# %% [markdown]
# ### 6. In this problem, we will compare the snowfall between Houghton and Marquette.
#
# - Use `.read_csv()` to read in the `GHCNd_Marquette.csv` file as `dfM`. Change the `skiprows` and `usecols` arguments as needed.
# - Add a new column `SNOW_IN` by converting the snowfall from mm to inches.
# - Slice the `SNOW_IN` data for 1991-2000 from both `dfH` and `dfM`.
# - Calculate the number of days on which the snowfall in Marquette is higher than Houghton.
# - Find the date on which the snowfall difference between Houghton and Marquette is the largest. Print the snowfall of both cities on that day.
# - Calculate the annual total snowfall from both cities, and make a marker line plot to show both time series. Use different colors for the cities and add the legend.

# %%
# Type your codes here

# %% [markdown]
# ### 7. Let's compare the temperature records between Houghton and Marquette.
# - Slice the `TMAX` data for 1991-2020 from both `dfH` and `dfM`.
# - Calculate the `TMAX` difference between the two cities. This only works when the `TMAX` Series have datetimeindex.
# - Calculate the number of days in each year on which the temperature in Marquette is above 20 degC and at least five degrees above that in Houghton.
# - Make a bar plot to show your result.
# - Calculate the number of days in each year on which the temperature in Houghton is below 0 degC and at least five degrees below that in Marquette.
# - Make a bar plot to show your result.

# %%
# Type your codes here
